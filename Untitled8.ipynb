# %% [markdown]
# <a href="https://colab.research.google.com/github/Thikshaya555/Divisive-Hierarchical-Clustering/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2q#covolutional neural network
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense,Dropout,Activation,Flatten
from keras.layers.convolutional import Conv2D,MaxPooling2D
from keras.optimizers import SGD,Adam,RMSprop
import matplotlib.pyplot as plt

IMG_CHANNELS=3
IMG_ROWS=32
IMG_COLS=32

BATCH_SIZE=128
NB_EPOCH=20
NB_CLASSES=10
VERBOSE=1
VALIDATION_SPLIT=0.2
OPTIM=RMSprop()
#load the data set into variable x_train( the variable that contains images to train on)y_train(contains labels of the image to train)x_test,y_test
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
#explore the data set knowing the type of data that we a
# Out:
# Using TensorFlow backend.
# ...
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 109.2MB 35kB/s
# ...
#      |████████████████████████████████| 3.2MB 37.1MB/s
# ...
#      |████████████████████████████████| 491kB 51.9MB/s
# ...
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorflow 2.2.0rc2
#     Uninstalling tensorflow-2.2.0rc2:
#       Successfully uninstalled tensorflow-2.2.0rc2
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
print(type(x_train))
print(type(x_test))
print(type(y_train))
print(type(y_test))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
# ...

# %%
y_train=np_utils.to_categorical(y_train,NB_CLASSES)
y_test=np_utils.to_categorical(y_test,NB_CLASSES)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_train/=255
x_test/=255

# %%
model=Sequential()
model.add(Conv2D(64,(3,3),padding='same',input_shape=(IMG_ROWS,IMG_COLS,IMG_CHANNELS)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0,25))

# %%
model.add(Flatten())
model.add(Dense(600))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 600)               9831000
# _________________________________________________________________
# activation_8 (Activation)    (None, 600)               0
# ...

# %%
model.compile(loss='categorical_crossentropy',optimizer=OPTIM,metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=BATCH_SIZE,epochs=5,validation_split=VALIDATION_SPLIT,verbose=VERBOSE)
score=model.evaluate(x_test,y_test,batch_size=BATCH_SIZE,verbose=VERBOSE)
print("test score:",score[0])
print("test accuracy",score[1])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/5
# 40000/40000 [==============================] - 115s 3ms/step - loss: 1.6995 - accuracy: 0.4104 - val_loss: 1.3825 - val_accuracy: 0.5111
# Epoch 2/5
# 40000/40000 [==============================] - 112s 3ms/step - loss: 1.2952 - accuracy: 0.5431 - val_loss: 1.1849 - val_accuracy: 0.5884
# Epoch 3/5
# 40000/40000 [==============================] - 112s 3ms/step - loss: 1.1389 - accuracy: 0.6012 - val_loss: 1.2353 - val_accuracy: 0.5732
# Epoch 4/5
# 40000/40000 [==============================] - 113s 3ms/step - loss: 1.0328 - accuracy: 0.6422 - val_loss: 1.1052 - val_accuracy: 0.6081
# Epoch 5/5
# ...
# 10000/10000 [==============================] - 7s 661us/step
# test score: 1.1192184776306153
# test accuracy 0.6129999756813049

# %%
from tkinter import *
import tkinter as tk
root=tk.Tk()
Label(root,text="First").grid(row=0)
e1=Entry(root)
e1.grid(row=0,column=1)
mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-117-a216dddaa50b> in <module>()
#       1 from tkinter import *
#       2 import tkinter as tk
# ----> 3 root=tk.Tk()
#       4 Label(root,text="First").grid(row=0)
#       5 e1=Entry(root)
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
import os
import matplotlib as mpl
if os.environ.get('DISPLAY','')=='':
  print('no display')
  mpl.use('Agg')
import matplotlib.pyplot as plt
# Out:
# no display

# %%
from Tkinter import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-103-f6f520fa05d6> in <module>()
# ----> 1 from Tkinter import *
#
# ModuleNotFoundError: No module named 'Tkinter'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install Tkinter
# Out:
# ERROR: Could not find a version that satisfies the requirement Tkinter (from versions: none)
# ERROR: No matching distribution found for Tkinter

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('ship.jpg')
# Out:
#      <input type="file" id="files-cd302fce-c4f7-44e7-8422-41456e062cb1" name="files[]" multiple disabled />
#      <output id="result-cd302fce-c4f7-44e7-8422-41456e062cb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ship.jpg to ship (2).jpg

# %%
model.save('model.h5')

# %%
model.load_weights('model.h5')

# %%
pip install anvil-uplink
# Out:
# ...
#      |████████████████████████████████| 61kB 1.9MB/s
# ...
#      |████████████████████████████████| 61kB 5.1MB/s
# ...
#   Created wheel for ws4py: filename=ws4py-0.5.1-cp36-none-any.whl size=45215 sha256=5c439e028579e1e1c8ba26bde5cd154ee064ba4430c5dd4d272993ca4e2ee0cd
#   Stored in directory: /root/.cache/pip/wheels/a2/6e/4e/8b0ae12fb9b8a05715256952cf7609a8ab86285fab99b88c68
# Successfully built ws4py
# ...

# %%
img=plt.imshow(my_image)
print(my_image)
# Out:
# [[[  0   2  44]
#   [ 82 109 154]
#   [111 147 199]
#   ...
#   [138 173 215]
#   [ 99 127 164]
#   [  0   5  37]]
#
#  [[  0   2  44]
#   [ 84 111 156]
#   [112 148 200]
#   ...
#   [138 173 215]
#   [ 99 127 164]
#   [  0   6  38]]
#
#  [[  0   3  45]
#   [ 85 112 157]
#   [114 150 202]
#   ...
#   [139 174 216]
#   [ 99 127 164]
#   [  0   6  38]]
#
#  ...
#
#  [[  0   6  25]
#   [ 31  57  80]
#   [ 35  62  92]
#   ...
#   [ 75  98 116]
#   [ 48  63  82]
#   [  0   9  27]]
#
#  [[  0   6  25]
#   [ 24  50  73]
#   [ 29  56  86]
#   ...
#   [ 62  84 105]
#   [ 40  55  74]
#   [  0   7  25]]
#
#  [[  0   8  27]
#   [ 30  56  79]
#   [ 39  66  96]
#   ...
#   [ 43  65  86]
#   [ 27  42  61]
#   [  0   0  19]]]

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)
print(my_image_resized)
# Out:
# [[[0.37647059 0.58039216 0.84313725]
#   [0.37254902 0.58039216 0.85      ]
#   [0.37156863 0.57941176 0.84705882]
#   ...
#   [0.45882353 0.65882353 0.88235294]
#   [0.45882353 0.65882353 0.88235294]
#   [0.45490196 0.65098039 0.86666667]]
#
#  [[0.42794118 0.63235294 0.86666667]
#   [0.43627451 0.64411765 0.87941176]
#   [0.41813725 0.6245098  0.8745098 ]
#   ...
#   [0.45980392 0.6627451  0.88627451]
#   [0.4627451  0.66372549 0.8872549 ]
#   [0.4627451  0.65735294 0.8745098 ]]
#
#  [[0.44705882 0.65490196 0.8745098 ]
#   [0.47843137 0.68235294 0.90539216]
#   [0.46029412 0.66666667 0.89803922]
#   ...
#   [0.46666667 0.67058824 0.89411765]
#   [0.49019608 0.69019608 0.90490196]
#   [0.50588235 0.69803922 0.89362745]]
#
#  ...
#
#  [[0.21078431 0.35196078 0.50098039]
#   [0.21078431 0.35294118 0.50490196]
#   [0.18431373 0.32598039 0.46715686]
#   ...
#   [0.12156863 0.25490196 0.36862745]
#   [0.10588235 0.23137255 0.33627451]
#   [0.10588235 0.22352941 0.32941176]]
#
# ...

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))

probabilities
# Out:
# array([[2.3559884e-05, 2.7333551e-06, 4.0559724e-02, 9.3715870e-01,
#         2.4081690e-03, 1.5442089e-02, 4.0937075e-03, 7.7284225e-05,
#         3.3769189e-05, 2.0026855e-04]], dtype=float32)

# %%
number_to_class=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class cat --probability: 0.9371587

# %%
import keras.backend.tensorflow_backend as tb
tb._SYMBOLIC_SCOPE.value=True

# %%
import anvil.server
anvil.server.connect("VRQIYI5V3DU5MXYZU3YHY5HI-VHK3DTXY3N74C7PZ")

# %%
import anvil.media
@anvil.server.callable
def classify_image(file):
    with anvil.media.TempFile(file) as filename:
        my_image=plt.imread(filename)
    img=resize(my_image,(32,32,3))
    
    probabilities=model.predict(np.array([img,]))
    number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
    index=np.argsort(probabilities[0,:])
    return (number_to_class[index[9]],float(probabilities[0,index[9]]))

# %%
my_image_resized=resize(my_image,(32,32,3))
img3=plt.imshow(my_image_resized)

# %%
pip uninstall keras
# Out:
# Uninstalling Keras-2.3.1:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/Keras-2.3.1.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/docs/*
#     /usr/local/lib/python3.6/dist-packages/keras/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.6/dist-packages/docs/md_autogen.py
#     /usr/local/lib/python3.6/dist-packages/docs/update_docs.py
# Proceed (y/n)? y
#   Successfully uninstalled Keras-2.3.1

# %%
pip install keras==2.2.5
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/ba/2d058dcf1b85b9c212cc58264c98a4a7dd92c989b798823cc5690d062bb2/Keras-2.2.5-py2.py3-none-any.whl
# ...
#   Found existing installation: Keras 2.3.0
#     Uninstalling Keras-2.3.0:
#       Successfully uninstalled Keras-2.3.0
# ...

# %%
from keras.preprocessing.image import load_img

# %%
my_image=plt.imread('ship.jpg')

# %%
img=plt.imshow(my_image)
print(img)
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('ship.jpg')
# Out:
#      <input type="file" id="files-b658a170-d358-4306-8808-9801a0d902e8" name="files[]" multiple disabled />
#      <output id="result-b658a170-d358-4306-8808-9801a0d902e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ship.jpg to ship (4).jpg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))

probabilities
# Out:
# array([[9.21097517e-01, 2.07062214e-04, 1.53229935e-02, 3.02837347e-03,
#         1.74677595e-02, 1.93232030e-03, 1.18428819e-04, 1.54930618e-04,
#         4.04758677e-02, 1.94712004e-04]], dtype=float32)

# %%
number_to_class=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class airplane --probability: 0.9210975

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('car1.jpg')
# Out:
#      <input type="file" id="files-5dba99e9-c1e6-42c6-ae4c-a6d3eb0aa2ce" name="files[]" multiple disabled />
#      <output id="result-5dba99e9-c1e6-42c6-ae4c-a6d3eb0aa2ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car1.jpg to car1.jpg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','bird','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class car --probability: 0.9681083

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('crow1.jpg')
# Out:
#      <input type="file" id="files-10f76ece-d9e7-4dde-a38b-a48eea0c2bfa" name="files[]" multiple disabled />
#      <output id="result-10f76ece-d9e7-4dde-a38b-a48eea0c2bfa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving crow1.jpg to crow1.jpg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class crow --probability: 0.91983277

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('deer.jpeg')
# Out:
#      <input type="file" id="files-9fd13cc6-254a-4074-b5a8-4837026fcb63" name="files[]" multiple disabled />
#      <output id="result-9fd13cc6-254a-4074-b5a8-4837026fcb63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving deer.jpeg to deer.jpeg

# %%
img=plt.imshow(my_image)

# %%
C

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class deer --probability: 0.9593184

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('frog.jpeg')
# Out:
#      <input type="file" id="files-707d555c-eb70-4929-8606-03a938582751" name="files[]" multiple disabled />
#      <output id="result-707d555c-eb70-4929-8606-03a938582751">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving frog.jpeg to frog.jpeg

# %%
img=plt.imshow(my_image)

# %%
C

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class frog --probability: 0.9999827

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('horse.jpg')
# Out:
#      <input type="file" id="files-a262e733-952d-4dff-aea8-db8f3edcc2a6" name="files[]" multiple disabled />
#      <output id="result-a262e733-952d-4dff-aea8-db8f3edcc2a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving horse.jpg to horse.jpg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class horse --probability: 0.9715888

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('doggy.jpeg')
# Out:
#      <input type="file" id="files-d7f610cf-d084-4bd7-9d69-d3faa54ffd80" name="files[]" multiple disabled />
#      <output id="result-d7f610cf-d084-4bd7-9d69-d3faa54ffd80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving doggy.jpeg to doggy.jpeg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class dog --probability: 0.9992403

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('truck.jpeg')
# Out:
#      <input type="file" id="files-d9bd90fb-3884-4432-b511-fc7d60a8aba4" name="files[]" multiple disabled />
#      <output id="result-d9bd90fb-3884-4432-b511-fc7d60a8aba4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving truck.jpeg to truck.jpeg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))
number_to_class=['airplane','car','crow','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class truck --probability: 0.854401

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('airoplane.jpg')
# Out:
#      <input type="file" id="files-848f005c-08be-41d1-91bb-5723800d9020" name="files[]" multiple disabled />
#      <output id="result-848f005c-08be-41d1-91bb-5723800d9020">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airoplane.jpg to airoplane.jpg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))

probabilities
# Out:
# array([[6.1709547e-01, 2.7388864e-04, 3.3615818e-03, 3.0260236e-04,
#         6.5042777e-04, 2.0028270e-07, 2.0213258e-04, 9.1012026e-08,
#         3.7727585e-01, 8.3768007e-04]], dtype=float32)

# %%
number_to_class=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class airplane --probability: 0.6170955

# %%
from google.colab import files
uploaded=files.upload()
my_image=plt.imread('catanddog.jpeg')
# Out:
#      <input type="file" id="files-d8979a48-66bf-4c14-8839-24f697942fbe" name="files[]" multiple disabled />
#      <output id="result-d8979a48-66bf-4c14-8839-24f697942fbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving catanddog.jpeg to catanddog (1).jpeg

# %%
img=plt.imshow(my_image)

# %%
from skimage.transform import resize
my_image_resized=resize(my_image,(32,32,3))
img=plt.imshow(my_image_resized)

# %%
import numpy as np
probabilities=model.predict(np.array([my_image_resized,]))

probabilities
# Out:
# array([[1.62138206e-10, 3.96216705e-11, 3.79785401e-04, 5.94275631e-03,
#         6.31215153e-06, 6.07717574e-01, 1.54243551e-08, 3.85953456e-01,
#         1.05411644e-13, 2.26562191e-09]], dtype=float32)

# %%
number_to_class=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
index=np.argsort(probabilities[0,:])
print('most likely class',number_to_class[index[9]],'--probability:',probabilities[0,index[9]])
# Out:
# most likely class dog --probability: 0.6077176
